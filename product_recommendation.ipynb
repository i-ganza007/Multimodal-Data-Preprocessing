# %% [markdown]
# <a href="https://colab.research.google.com/github/i-ganza007/Multimodal-Data-Preprocessing/blob/main/product_recommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
customer_social_profiles = pd.read_excel('/content/Copy of customer_social_profiles.xlsx')
customer_transactions = pd.read_excel('/content/Copy of customer_transactions.xlsx')
customer_social_profiles.head()
customer_transactions.head()
# Out:
#    customer_id_legacy  transaction_id  purchase_amount purchase_date  \
# 0                 151            1001              408    2024-01-01
# 1                 192            1002              332    2024-01-02
# 2                 114            1003              442    2024-01-03
# 3                 171            1004              256    2024-01-04
# 4                 160            1005               64    2024-01-05
#
#   product_category  customer_rating
# 0           Sports              2.3
# 1      Electronics              4.2
# 2      Electronics              2.1
# 3         Clothing              2.8
# 4         Clothing              1.3

# %%
joined_set = customer_social_profiles.join(customer_transactions)
# joined_set.fillna(joined_set['customer_rating'].mean)
joined_set_filled = joined_set.fillna(joined_set['customer_rating'].mean())
# Out:
#     customer_id_new social_media_platform  engagement_score  \
# 0              A178              LinkedIn                74
# 1              A190               Twitter                82
# 2              A150              Facebook                96
# 3              A162               Twitter                89
# 4              A197               Twitter                92
# ..              ...                   ...               ...
# 150            A125              LinkedIn                66
# 151            A116               Twitter                78
# 152            A189               Twitter                59
# 153            A162               Twitter                71
# 154            A155                TikTok                98
#
#      purchase_interest_score review_sentiment  customer_id_legacy  \
# 0                        4.9         Positive             151.000
# 1                        4.8          Neutral             192.000
# 2                        1.6         Positive             114.000
# 3                        2.6         Positive             171.000
# 4                        2.3          Neutral             160.000
# ..                       ...              ...                 ...
# 150                      4.7         Positive               2.985
# 151                      1.1         Negative               2.985
# 152                      3.8          Neutral               2.985
# 153                      4.8         Positive               2.985
# 154                      4.8         Positive               2.985
#
#      transaction_id  purchase_amount        purchase_date product_category  \
# 0          1001.000          408.000  2024-01-01 00:00:00           Sports
# 1          1002.000          332.000  2024-01-02 00:00:00      Electronics
# 2          1003.000          442.000  2024-01-03 00:00:00      Electronics
# 3          1004.000          256.000  2024-01-04 00:00:00         Clothing
# 4          1005.000           64.000  2024-01-05 00:00:00         Clothing
# ..              ...              ...                  ...              ...
# 150           2.985            2.985                2.985            2.985
# 151           2.985            2.985                2.985            2.985
# 152           2.985            2.985                2.985            2.985
# 153           2.985            2.985                2.985            2.985
# 154           2.985            2.985                2.985            2.985
#
#      customer_rating
# 0              2.300
# 1              4.200
# 2              2.100
# 3              2.800
# 4              1.300
# ..               ...
# 150            2.985
# 151            2.985
# 152            2.985
# 153            2.985
# 154            2.985
#
# [155 rows x 11 columns]
